# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
S = [1, 2, 3, 4, 6, 9, 13, 19, 28, 42, 63, 94, 141, 211, 316, 474, 711, 1066, 1599, 2398, 3597, 5395, 8092]
R = [20.0, 46.0, 44.0, 58.0, 66.0, 67.0, 80.0, 88.0, 88.0, 92.0, 96.0, 99.0, 99.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0]
Q = [64568.409, 34885.895, 14757.867, 34354.935, 17296.274, 17891.639, 12840.645, 9084.648, 6894.912, 5414.296, 3955.567, 3471.073, 2877.881, 2592.552, 2285.74, 1872.234, 1745.344, 1636.869, 1535.486, 1519.381, 1330.196, 1522.801, 1590.46]

# %%
fig = plt.figure()
ax = fig.gca()
ax.set_xticks(np.arange(0, 100, 5))
ax.set_yticks(np.arange(0, 4*10**4, 5*10**3))
plt.plot(R, Q)
plt.xlim(60, 100)
plt.ylim(0, 4 * 10 ** 4)
plt.grid()
plt.show()

# %%
plt.plot(S, R)
plt.xlim(1, 256)
plt.xscale('log')
plt.show()
